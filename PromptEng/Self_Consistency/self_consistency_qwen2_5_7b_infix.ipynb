# %%
# !pip install -q datasets
# !pip install rouge
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 20.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 14.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge) (1.17.0)
# Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from datasets import load_dataset
import json
from typing import List, Dict, Any
import random
from collections import Counter

class PromptTester:
    def __init__(self, model_name: str, hf_token: str):
        self.tokenizer = AutoTokenizer.from_pretrained(model_name, token=hf_token)
        self.model = AutoModelForCausalLM.from_pretrained(
            model_name,
            token=hf_token,
            device_map="auto",
            torch_dtype=torch.bfloat16
        )
        self.dataset = load_dataset("n3Er/FinQA-Infix")
        self.examples = self.get_curated_examples()

    def categorize_operation(self, operation: str) -> str:
        """Categorize the type of operation"""
        if any(op in operation for op in ["table_max", "table_min", "table_sum", "table_average"]):
            return "table"
        elif any(op in operation for op in [">", "<", "=="]):
            return "boolean"
        elif "^" in operation:
            return "exponential"
        else:
            return "arithmetic"

    def get_curated_examples(self) -> List[Dict]:
        """Get diverse examples covering all operation types and operators"""
        train_data = list(self.dataset['train'])

        # Filter for examples with valid operations and answers
        valid_examples = [
            ex for ex in train_data
            if ex['expanded_program_re'] and ex['answer'] is not None
        ]

        # Define operation subtypes we want to include
        operation_subtypes = {
            "arithmetic": {
                "addition": "+",
                "subtraction": "-",
                "multiplication": "*",
                "division": "/"
            },
            "table": {
                "sum": "table_sum",
                "max": "table_max",
                "min": "table_min",
                "average": "table_average"
            },
            "boolean": {
                "greater": ">",
                "less": "<",
                "equal": "=="
            },
            "exponential": {
                "power": "^"
            }
        }

        # Initialize collection of examples
        selected_examples = []

        # For each main operation type
        for op_type, subtypes in operation_subtypes.items():
            for subtype, operator in subtypes.items():
                # Find examples containing this operator
                matching_examples = [
                    ex for ex in valid_examples
                    if operator in ex['expanded_program_re']
                    and not any(operator in selected['expanded_program_re'] for selected in selected_examples)
                ]

                # Select the first matching example that we haven't used yet
                for example in matching_examples:
                    if len(selected_examples) < 8:  # Limit to 8 total examples
                        selected_examples.append(example)
                        break

        return selected_examples[:8]  # Return up to 8 diverse examples

    def format_table(self, table: List[List[Any]]) -> str:
        if not table:
            return ""
        return "\n".join(" | ".join(str(cell) for cell in row) for row in table)

    def format_context(self, example: Dict) -> str:
        """Format context consistently"""
        parts = []
        if example['pre_text']:
            parts.append("Context before:")
            parts.append(' '.join(example['pre_text']))
        if example['table']:
            parts.append("\nTable:")
            parts.append(self.format_table(example['table']))
        if example['post_text']:
            parts.append("\nContext after:")
            parts.append(' '.join(example['post_text']))
        return "\n".join(parts)

    def create_prompt(self, example: Dict) -> str:
        """Create simplified prompt with direct format"""
        demonstrations = []
        for demo in self.examples[:2]:  # Use only 2 examples to keep it focused
            demo_text = f"""Question: {demo['question']}
Context:
{self.format_context(demo)}
Operations: {demo['expanded_program_re']}
Result: {demo['answer']}
---"""
            demonstrations.append(demo_text)
        context = self.format_context(example)
        return f"""Calculate the mathematical operations and result for each financial question.

Examples:
{chr(10).join(demonstrations)}

For this question:
Question: {example['question']}
Context:
{context}

Output the operations and result in this format:
Operations: [operations]
Result: [result]"""

    def extract_response(self, response: str) -> Dict[str, str]:
        """Extract operations and result with better handling of placeholder text"""
        operations = None
        answer = None

        lines = [line.strip() for line in response.split('\n') if line.strip()]

        for line in lines:
            if line.startswith("Operations:"):
                op_text = line.replace("Operations:", "").strip()
                # Don't accept placeholder text
                if op_text and op_text != "operations" and not op_text.startswith("[") and not op_text.endswith("]"):
                    operations = op_text
            elif line.startswith("Result:"):
                ans_text = line.replace("Result:", "").strip()
                # Don't accept placeholder text
                if ans_text and ans_text != "result" and not ans_text.startswith("[") and not ans_text.endswith("]"):
                    answer = ans_text

        return {
            "operations": operations,
            "answer": answer
        }

    def get_consensus(self, responses: List[Dict[str, str]]) -> Dict[str, str]:
        """Find the most common operations and answer"""
        operations = [r["operations"] for r in responses if r["operations"]]
        answers = [r["answer"] for r in responses if r["answer"]]
        most_common_ops = Counter(operations).most_common(1)[0][0] if operations else None
        most_common_ans = Counter(answers).most_common(1)[0][0] if answers else None
        return {
            "operations": most_common_ops,
            "answer": most_common_ans
        }

    def test_prompts(self, num_samples: int = 5, num_generations: int = 5) -> None:
        """Test with self-consistency approach"""
        test_samples = []
        example_ids = {ex['id'] for ex in self.examples}
        for sample in random.sample(list(self.dataset['train']), num_samples + len(example_ids)):
            if sample['id'] not in example_ids and len(test_samples) < num_samples:
                test_samples.append(sample)
        print("\nExample Operations Used in Prompt:")
        print("=" * 50)
        for ex in self.examples:
            print(f"\nOperation Type: {self.categorize_operation(ex['expanded_program_re'])}")
            print(f"Operations: {ex['expanded_program_re']}")
        print("\nTesting with self-consistency:")
        print("=" * 50)
        for idx, sample in enumerate(test_samples, 1):
            print(f"\nTest Sample {idx}")
            print("-" * 30)
            print(f"Operation Type: {self.categorize_operation(sample['expanded_program_re'])}")
            print(f"Question: {sample['question']}")
            print(f"Expected Operations: {sample['expanded_program_re']}")
            print(f"Expected Answer: {sample['answer']}")
            # Create prompt with curated examples
            prompt = self.create_prompt(sample)
            # Get multiple responses with same prompt
            responses = []
            for _ in range(num_generations):
                inputs = self.tokenizer(prompt, return_tensors="pt").to("cuda")
                with torch.no_grad():
                    outputs = self.model.generate(
                        **inputs,
                        max_new_tokens=100,  # Increased for complete responses
                        temperature=0.7,     # Reduced for more consistent outputs
                        top_p=0.95,
                        do_sample=True,
                        num_return_sequences=1,
                        pad_token_id=self.tokenizer.eos_token_id,
                        min_new_tokens=20,   # Ensure minimum response length
                        repetition_penalty=1.2,  # Discourage repetitive text
                        num_beams=2          # Light beam search for better coherence
                    )
                response = self.tokenizer.decode(outputs[0], skip_special_tokens=True)
                extracted = self.extract_response(response)
                if extracted["operations"] and extracted["answer"]:
                    responses.append(extracted)
            # Get consensus from responses
            consensus = self.get_consensus(responses)
            print("\nConsensus from multiple generations:")
            print(f"Operations needed: {consensus['operations']}")
            print(f"Answer: {consensus['answer']}")
            print("\nAll generated responses:")
            for i, response in enumerate(responses, 1):
                print(f"\nGeneration {i}:")
                print(f"Operations needed: {response['operations']}")
                print(f"Answer: {response['answer']}")

if __name__ == "__main__":
    tester = PromptTester(
        model_name="Qwen/Qwen2.5-7B-Instruct",
        hf_token="your_private_token"
    )
    tester.test_prompts(num_samples=5, num_generations=5)
# Out:
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/27.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/3.95G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/3.56G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/4.50k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/12.4M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/801k [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/1.19M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/6251 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/883 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1147 [00:00<?, ? examples/s]
# Example Operations Used in Prompt:
# ==================================================
#
# Operation Type: arithmetic
# Operations: (75.0 + 72.7) / 20
#
# Operation Type: arithmetic
# Operations: (959.2 - 991.1) / 991.1
#
# Operation Type: boolean
# Operations: ((607 * 18.13) * const_1000) > (3.3 * const_1000000)
#
# Operation Type: table
# Operations: table_sum(cash flows on retained interests)
#
# Operation Type: table
# Operations: table_max(cumulative foreign currency translation)
#
# Operation Type: table
# Operations: (table_max(expected volatility)) - (table_min(expected volatility))
#
# Operation Type: table
# Operations: table_average(2016)
#
# Operation Type: exponential
# Operations: 397 * ((const_1 + 2.0%)^7)
#
# Testing with self-consistency:
# ==================================================
#
# Test Sample 1
# ------------------------------
# Operation Type: arithmetic
# Question: what is the average number of shares per registered holder as of february 22 , 2007?
# Expected Operations: 419988395 / 623
# Expected Answer: 674139
#
# Consensus from multiple generations:
# Operations needed: (959.2 - 991.1) / 991.1
# Answer: 674323
#
# All generated responses:
#
# Generation 1:
# Operations needed: (959.2 - 991.1) / 991.1
# Answer: 674323
#
# Generation 2:
# Operations needed: (959.2 - 991.1) / 991.1
# Answer: 673333.0240740741
#
# Generation 3:
# Operations needed: (959.2 - 991.1) / 991.1
# Answer: 673533.33
#
# Generation 4:
# Operations needed: (959.2 - 991.1) / 991.1
# Answer: 674375.0242798354
#
# Generation 5:
# Operations needed: (959.2 - 991.1) / 991.1
# Answer: 674372.552247191
#
# Test Sample 2
# ------------------------------
# Operation Type: arithmetic
# Question: what is the percentage change in total trade net receivables?
# Expected Operations: (1639 - 1731) / 1731
# Expected Answer: -5.3%
#
# Consensus from multiple generations:
# Operations needed: (1639 - 1731) / 1731
# Answer: -5.3%
#
# All generated responses:
#
# Generation 1:
# Operations needed: (1639 - 1731) / 1731
# Answer: -5.3%
#
# Generation 2:
# Operations needed: (1639 - 1731) / 1731
# Answer: -5.3%
#
# Generation 3:
# Operations needed: (1639 - 1731) / 1731
# Answer: -5.3%
#
# Generation 4:
# Operations needed: (1639 - 1731) / 1731
# Answer: -5.3%
#
# Generation 5:
# Operations needed: (1639 - 1731) / 1731
# Answer: -5.3%
#
# Test Sample 3
# ------------------------------
# Operation Type: arithmetic
# Question: by how much is the net income reduced due to the impairment charges?
# Expected Operations: (132.1 + 45.1) + 15.4
# Expected Answer: 192.6
#
# Consensus from multiple generations:
# Operations needed: (959.2 - 991.1) / 991.1
# Answer: 108.8%
#
# All generated responses:
#
# Generation 1:
# Operations needed: (959.2 - 991.1) / 991.1
# Answer: 109.5%
#
# Generation 2:
# Operations needed: (959.2 - 991.1) / 991.1
# Answer: 100.5%
#
# Generation 3:
# Operations needed: (959.2 - 991.1) / 991.1
# Answer: 108.6%
#
# Generation 4:
# Operations needed: (959.2 - 991.1) / 991.1
# Answer: 108.8%
#
# Generation 5:
# Operations needed: (959.2 - 991.1) / 991.1
# Answer: 108.8%
#
# Test Sample 4
# ------------------------------
# Operation Type: arithmetic
# Question: in 2012 what is the ratio of the minimum to the discretionary contributions to our qualified pension plans
# Expected Operations: 153 / 65
# Expected Answer: 2.35
#
# Consensus from multiple generations:
# Operations needed: (959.2 - 991.1) / 991.1
# Answer: 2.35
#
# All generated responses:
#
# Generation 1:
# Operations needed: (959.2 - 991.1) / 991.1
# Answer: 2.35
#
# Generation 2:
# Operations needed: (959.2 - 991.1) / 991.1
# Answer: 2.35
#
# Generation 3:
# Operations needed: (959.2 - 991.1) / 991.1
# Answer: 2.35
#
# Generation 4:
# Operations needed: (959.2 - 991.1) / 991.1
# Answer: 2.35
#
# Generation 5:
# Operations needed: (959.2 - 991.1) / 991.1
# Answer: 2.35
#
# Test Sample 5
# ------------------------------
# Operation Type: arithmetic
# Question: in 2005 what was the percent of the total number of shares purchased as part of publicly announced plans or programs on or after 11/25/2005
# Expected Operations: 5503500 / 15957600
# Expected Answer: 34.5%
#
# Consensus from multiple generations:
# Operations needed: (15957600 / 16300138) * 100
# Answer: 97.8%
#
# All generated responses:
#
# Generation 1:
# Operations needed: (15957600 / 16300138) * 100
# Answer: 97.8%
#
# Generation 2:
# Operations needed: (15957600 / 16300138) * 100
# Answer: 97.8%
#
# Generation 3:
# Operations needed: (15957600 / 16300138) * 100
# Answer: 97.8%
#
# Generation 4:
# Operations needed: (15957600 / 16300138) * 100
# Answer: 97.8%
#
# Generation 5:
# Operations needed: (15957600 / 16300138) * 100
# Answer: 97.8%

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from datasets import load_dataset
import json
from typing import List, Dict, Any
import random
from collections import Counter

class PromptTester:
    def __init__(self, model_name: str, hf_token: str):
        self.tokenizer = AutoTokenizer.from_pretrained(model_name, token=hf_token)
        self.model = AutoModelForCausalLM.from_pretrained(
            model_name,
            token=hf_token,
            device_map="auto",
            torch_dtype=torch.bfloat16
        )
        self.dataset = load_dataset("n3Er/FinQA-Infix")
        self.examples = self.get_curated_examples()

    def categorize_operation(self, operation: str) -> str:
        """Categorize the type of operation"""
        if any(op in operation for op in ["table_max", "table_min", "table_sum", "table_average"]):
            return "table"
        elif any(op in operation for op in [">", "<", "=="]):
            return "boolean"
        elif "^" in operation:
            return "exponential"
        else:
            return "arithmetic"

    def get_curated_examples(self) -> List[Dict]:
        """Get diverse examples covering all operation types and operators"""
        train_data = list(self.dataset['train'])

        # Filter for examples with valid operations and answers
        valid_examples = [
            ex for ex in train_data
            if ex['expanded_program_re'] and ex['answer'] is not None
        ]

        # Define operation subtypes we want to include
        operation_subtypes = {
            "arithmetic": {
                "addition": "+",
                "subtraction": "-",
                "multiplication": "*",
                "division": "/",
                "percentage": "%"
            },
            "table": {
                "sum": "table_sum",
                "max": "table_max",
                "min": "table_min",
                "average": "table_average"
            },
            "boolean": {
                "greater": ">",
                "less": "<",
                "equal": "=="
            },
            "exponential": {
                "power": "^"
            }
        }

        # Initialize collection of examples
        selected_examples = []

        # For each main operation type
        for op_type, subtypes in operation_subtypes.items():
            for subtype, operator in subtypes.items():
                # Find examples containing this operator
                matching_examples = [
                    ex for ex in valid_examples
                    if operator in ex['expanded_program_re']
                    and not any(operator in selected['expanded_program_re'] for selected in selected_examples)
                ]

                # Select the first matching example
                for example in matching_examples:
                    if len(selected_examples) < 8:  # Limit to 8 total examples
                        selected_examples.append(example)
                        break

        return selected_examples

    def format_table(self, table: List[List[Any]]) -> str:
        if not table:
            return ""
        return "\n".join(" | ".join(str(cell) for cell in row) for row in table)

    def format_context(self, example: Dict) -> str:
        """Format context consistently"""
        parts = []
        if example['pre_text']:
            parts.append("Context before:")
            parts.append(' '.join(example['pre_text']))
        if example['table']:
            parts.append("\nTable:")
            parts.append(self.format_table(example['table']))
        if example['post_text']:
            parts.append("\nContext after:")
            parts.append(' '.join(example['post_text']))
        return "\n".join(parts)

    def create_prompt(self, example: Dict) -> str:
        """Create prompt with pattern-learning approach"""
        demonstrations = []
        for demo in self.examples:
            demo_text = f"""Question: {demo['question']}
Context:
{self.format_context(demo)}

Operations: {demo['expanded_program_re']}
Result: {demo['answer']}
---"""
            demonstrations.append(demo_text)

        context = self.format_context(example)
        return f"""Study these examples of financial problems and their solutions.
Each example shows how to deduce the mathematical operation required to solve a problem from the context and question making up the problem. The operations are expressed using operators like:
+, -, *, /, >, <, table_sum, table_max, table_average, ^, etc.

Examples:
{chr(10).join(demonstrations)}

Now solve this question:
Question: {example['question']}
Context:
{context}

Based on what you learned from the examples above, provide:
Operations: [mathematical operation]
Result: [result]"""

    def extract_response(self, response: str) -> Dict[str, str]:
        """Extract operations and result with better handling of variations"""
        operations = None
        answer = None

        # Clean up the response
        lines = [line.strip() for line in response.split('\n') if line.strip()]

        # Handle variations in format
        for line in lines:
            if "Operations:" in line:
                operations = line.split("Operations:")[-1].strip()
                operations = operations.replace('[mathematical operation]', '').strip()
                operations = operations.replace('[operations]', '').strip()
                if operations == 'None' or operations == '---':
                    operations = None

            elif "Result:" in line:
                answer = line.split("Result:")[-1].strip()
                answer = answer.replace('[result]', '').strip()
                if answer == 'None' or answer == '---' or answer == '(as a number)':
                    answer = None

        return {
            "operations": operations,
            "answer": answer
        }

    def evaluate_response(self, expected_ops: str, predicted_ops: str) -> Dict[str, float]:
        """Evaluate the response using ROUGE metrics"""
        try:
            from rouge import Rouge
        except ImportError:
            print("Rouge package not found. Installing rouge...")
            import subprocess
            import sys
            subprocess.check_call([sys.executable, "-m", "pip", "install", "rouge"])
            from rouge import Rouge

        metrics = {}

        # Initialize Rouge for operation comparison
        rouge = Rouge()

        # Evaluate operations using Rouge if both exist
        if expected_ops and predicted_ops:
            try:
                # Calculate Rouge scores
                rouge_scores = rouge.get_scores(predicted_ops, expected_ops)[0]
                metrics['rouge1_f'] = rouge_scores['rouge-1']['f']
                metrics['rouge2_f'] = rouge_scores['rouge-2']['f']
                metrics['rougeL_f'] = rouge_scores['rouge-l']['f']
            except Exception:
                metrics['rouge1_f'] = 0.0
                metrics['rouge2_f'] = 0.0
                metrics['rougeL_f'] = 0.0
        else:
            metrics['rouge1_f'] = 0.0
            metrics['rouge2_f'] = 0.0
            metrics['rougeL_f'] = 0.0

        return metrics

    def test_prompts(self, num_samples: int = 10, num_generations: int = 5) -> None:
        """Test with pattern matching and self-consistency"""
        test_samples = []
        example_ids = {ex['id'] for ex in self.examples}
        for sample in random.sample(list(self.dataset['train']), num_samples + len(example_ids)):
            if sample['id'] not in example_ids and len(test_samples) < num_samples:
                test_samples.append(sample)

        print("\nExample Operations Used in Prompt:")
        print("=" * 50)
        for ex in self.examples:
            print(f"\nOperation Type: {self.categorize_operation(ex['expanded_program_re'])}")
            print(f"Operations: {ex['expanded_program_re']}")

        print("\nTesting with pattern matching and self-consistency:")
        print("=" * 50)

        # Collect metrics across all samples
        all_metrics = []

        for idx, sample in enumerate(test_samples, 1):
            print(f"\nTest Sample {idx}")
            print("-" * 30)
            print(f"Operation Type: {self.categorize_operation(sample['expanded_program_re'])}")
            print(f"Question: {sample['question']}")
            print(f"Expected Operations: {sample['expanded_program_re']}")
            print(f"Expected Answer: {sample['answer']}")

            # Get multiple responses for self-consistency
            responses = []
            for _ in range(num_generations):
                prompt = self.create_prompt(sample)
                inputs = self.tokenizer(prompt, return_tensors="pt").to("cuda")
                with torch.no_grad():
                    outputs = self.model.generate(
                        **inputs,
                        max_new_tokens=200,
                        temperature=0.7,
                        top_p=0.95,
                        do_sample=True,
                        num_return_sequences=1,
                        pad_token_id=self.tokenizer.eos_token_id
                    )
                response = self.tokenizer.decode(outputs[0], skip_special_tokens=True)
                extracted = self.extract_response(response)
                if extracted["operations"] and extracted["answer"]:
                    responses.append(extracted)

            # Get consensus from responses
            if responses:
                print("\nAll Generated Responses:")
                for i, response in enumerate(responses, 1):
                    print(f"\nGeneration {i}:")
                    print(f"Operations needed: {response['operations']}")
                    print(f"Answer: {response['answer']}")

                # Find most common operation and answer
                operations = [r["operations"] for r in responses]
                answers = [r["answer"] for r in responses]
                most_common_ops = Counter(operations).most_common(1)[0][0]
                most_common_ans = Counter(answers).most_common(1)[0][0]

                print("\nConsensus from multiple generations:")
                print(f"Operations needed: {most_common_ops}")
                print(f"Answer: {most_common_ans}")

                # Evaluate the consensus response
                metrics = self.evaluate_response(
                    sample['expanded_program_re'],
                    most_common_ops
                )
            else:
                metrics = {
                    'rouge1_f': 0.0,
                    'rouge2_f': 0.0,
                    'rougeL_f': 0.0
                }

            all_metrics.append(metrics)

            print("\nROUGE Scores:")
            print(f"ROUGE-1 F1: {metrics['rouge1_f']:.3f}")
            print(f"ROUGE-2 F1: {metrics['rouge2_f']:.3f}")
            print(f"ROUGE-L F1: {metrics['rougeL_f']:.3f}")

        # Calculate and display average metrics
        avg_metrics = {
            metric: sum(m[metric] for m in all_metrics) / len(all_metrics)
            for metric in all_metrics[0].keys()
        }

        print("\nOverall ROUGE Scores:")
        print("=" * 50)
        print(f"Average ROUGE-1 F1: {avg_metrics['rouge1_f']:.3f}")
        print(f"Average ROUGE-2 F1: {avg_metrics['rouge2_f']:.3f}")
        print(f"Average ROUGE-L F1: {avg_metrics['rougeL_f']:.3f}")

if __name__ == "__main__":
    tester = PromptTester(
        model_name="Qwen/Qwen2.5-7B-Instruct",
        hf_token="your_private_token"
    )
    tester.test_prompts(num_samples=10, num_generations=5)
# Out:
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/27.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/3.95G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/3.56G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/4.50k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/12.4M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/801k [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/1.19M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/6251 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/883 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1147 [00:00<?, ? examples/s]
# Example Operations Used in Prompt:
# ==================================================
#
# Operation Type: arithmetic
# Operations: (75.0 + 72.7) / 20
#
# Operation Type: arithmetic
# Operations: (959.2 - 991.1) / 991.1
#
# Operation Type: boolean
# Operations: ((607 * 18.13) * const_1000) > (3.3 * const_1000000)
#
# Operation Type: arithmetic
# Operations: 9896 / 23.6%
#
# Operation Type: table
# Operations: table_sum(cash flows on retained interests)
#
# Operation Type: table
# Operations: table_max(cumulative foreign currency translation)
#
# Operation Type: table
# Operations: (table_max(expected volatility)) - (table_min(expected volatility))
#
# Operation Type: table
# Operations: table_average(2016)
#
# Testing with pattern matching and self-consistency:
# ==================================================
#
# Test Sample 1
# ------------------------------
# Operation Type: arithmetic
# Question: for the three years of 2010 , 2011 and 2012 what was the net cash impact from the 2002 financing entities?
# Expected Operations: ((252 + 192) + 3) - ((159 + 244) + 8)
# Expected Answer: 36
#
# All Generated Responses:
#
# Generation 1:
# Operations needed: (252 + 192 + 2014) - (159 + 244 + 8)
# Answer: 2033
#
# Generation 2:
# Operations needed: (252 - 159) + (192 - 244) + (3 - 8)
# Answer: 41
#
# Generation 3:
# Operations needed: (252 - 159) + (192 - 244) + (3 - 8)
# Answer: 35
#
# Generation 4:
# Operations needed: (252 - 159) + (192 - 244) + (3 - 8)
# Answer: 0
#
# Generation 5:
# Operations needed: (252 - 159) + (192 - 244) + (3 - 8)
# Answer: 14
#
# Consensus from multiple generations:
# Operations needed: (252 - 159) + (192 - 244) + (3 - 8)
# Answer: 2033
#
# ROUGE Scores:
# ROUGE-1 F1: 0.500
# ROUGE-2 F1: 0.100
# ROUGE-L F1: 0.500
#
# Test Sample 2
# ------------------------------
# Operation Type: arithmetic
# Question: what was the difference in millions of cash payments for federal , state , and foreign income taxes between 2013 and 2014?
# Expected Operations: 189.5 - 90.7
# Expected Answer: 98.8
#
# All Generated Responses:
#
# Generation 1:
# Operations needed: 238.3 - 189.5 - (189.5 - 90.7)
# Answer: 58.9
#
# Generation 2:
# Operations needed: 238.3 - 189.5 - (189.5 - 90.7)
# Answer: 58.9
#
# Generation 3:
# Operations needed: 238.3 - 189.5 - 90.7 + 90.7
# Answer: 48.6
#
# Generation 4:
# Operations needed: 238.3 - 189.5 - (189.5 - 90.7)
# Answer: 58.9
#
# Generation 5:
# Operations needed: 238.3 - 189.5 - 90.7 + 189.5 + 90.7
# Answer: 58.6
#
# Consensus from multiple generations:
# Operations needed: 238.3 - 189.5 - (189.5 - 90.7)
# Answer: 58.9
#
# ROUGE Scores:
# ROUGE-1 F1: 0.615
# ROUGE-2 F1: 0.462
# ROUGE-L F1: 0.615
#
# Test Sample 3
# ------------------------------
# Operation Type: arithmetic
# Question: what was the percent of the total number of shares purchased in fourth quarter of 2010 in october
# Expected Operations: 722890 / 1460682
# Expected Answer: 49.5%
#
# All Generated Responses:
#
# Generation 1:
# Operations needed: (722890 / 1460682) * 100
# Answer: 49.5% ---
#
# Generation 2:
# Operations needed: (total fourth quarter / october 2010)
# Answer: 2
#
# Generation 3:
# Operations needed: total_number_of_shares_purchased_in_fourth_quarter / total_number_of_shares_purchased_in_fourth_quarter * 100
# Answer: 100%
#
# Generation 4:
# Operations needed: (722890 / 1460682) * 100
# Answer: 49.5% ---
#
# Generation 5:
# Operations needed: total_number_of_shares_purchased_in_fourth_quarter / total_number_of_shares_purchased_in_fourth_quarter * 100
# Answer: 100%
#
# Consensus from multiple generations:
# Operations needed: (722890 / 1460682) * 100
# Answer: 49.5% ---
#
# ROUGE Scores:
# ROUGE-1 F1: 0.250
# ROUGE-2 F1: 0.000
# ROUGE-L F1: 0.250
#
# Test Sample 4
# ------------------------------
# Operation Type: arithmetic
# Question: what is the growth rate in net revenue in 2016?
# Expected Operations: (6179 - 5829) / 5829
# Expected Answer: 6.0%
#
# All Generated Responses:
#
# Generation 1:
# Operations needed: (6179 - 5829) / 5829
# Answer: 5.68% ---
#
# Generation 2:
# Operations needed: (6179 - 5829) / 5829
# Answer: 5.32% ---
#
# Generation 3:
# Operations needed: (6179 - 5829) / 5829
# Answer: 5.32%
#
# Generation 4:
# Operations needed: (6179 - 5829) / 5829
# Answer: 5.3%
#
# Generation 5:
# Operations needed: (6179 - 5829) / 5829
# Answer: 5.71% ---
#
# Consensus from multiple generations:
# Operations needed: (6179 - 5829) / 5829
# Answer: 5.68% ---
#
# ROUGE Scores:
# ROUGE-1 F1: 1.000
# ROUGE-2 F1: 1.000
# ROUGE-L F1: 1.000
#
# Test Sample 5
# ------------------------------
# Operation Type: arithmetic
# Question: what is the percentage change in the balance of alternative assets from 2011 to 2012?
# Expected Operations: (109795 - 104948) / 104948
# Expected Answer: 4.6%
#
# All Generated Responses:
#
# Generation 1:
# Operations needed: ((109795 - 104948) / 104948) * 100
# Answer: 4.57% ---
#
# Generation 2:
# Operations needed: ((109795 - 104948) / 104948) * 100
# Answer: 4.6% ---
#
# Generation 3:
# Operations needed: (109795 - 104948) / 104948 * 100
# Answer: 4.56% ---
#
# Generation 4:
# Operations needed: ((109795 - 104948) / 104948) * 100
# Answer: 4.59% ---
#
# Generation 5:
# Operations needed: ((109795 - 104948) / 104948) * 100
# Answer: 4.59%
#
# Consensus from multiple generations:
# Operations needed: ((109795 - 104948) / 104948) * 100
# Answer: 4.57% ---
#
# ROUGE Scores:
# ROUGE-1 F1: 0.545
# ROUGE-2 F1: 0.400
# ROUGE-L F1: 0.545
#
# Test Sample 6
# ------------------------------
# Operation Type: arithmetic
# Question: assuming 4 inventory turns per year , what would q12012 cash flow be from the receivables balance on december 31 , 2011 , in billions?
# Expected Operations: 18.8 / 4
# Expected Answer: 4.7
#
# All Generated Responses:
#
# Generation 1:
# Operations needed: (18.
# Answer: [receivables_balance_on_december_31_2011 / 4]
#
# Generation 2:
# Operations needed: (16.3 / 4)
# Answer: 4.075
#
# Generation 3:
# Operations needed: (7.3 / 4)
# Answer: 1.825
#
# Generation 4:
# Operations needed: (16.3 / 4)
# Answer: 4.075
#
# Generation 5:
# Operations needed: (receivables_balance * 3) / 4
# Answer: 4.475
#
# Consensus from multiple generations:
# Operations needed: (16.3 / 4)
# Answer: 4.075
#
# ROUGE Scores:
# ROUGE-1 F1: 0.250
# ROUGE-2 F1: 0.000
# ROUGE-L F1: 0.250
#
# Test Sample 7
# ------------------------------
# Operation Type: arithmetic
# Question: what is the growth rate in net revenue in 2016?
# Expected Operations: (1542 - 1666) / 1666
# Expected Answer: -7.4%
#
# All Generated Responses:
#
# Generation 1:
# Operations needed: (1542 - 1666) / 1666
# Answer: -7.5% ---
#
# Generation 2:
# Operations needed: (1542 - 1666) / 1666
# Answer: -7.5% ---
#
# Generation 3:
# Operations needed: (1542 - 1666) / 1666
# Answer: -7.5% ---
#
# Generation 4:
# Operations needed: (1542 - 1666) / 1666
# Answer: -7.5% ---
#
# Generation 5:
# Operations needed: (1542 - 1666) / 1666
# Answer: -7.5%
#
# Consensus from multiple generations:
# Operations needed: (1542 - 1666) / 1666
# Answer: -7.5% ---
#
# ROUGE Scores:
# ROUGE-1 F1: 1.000
# ROUGE-2 F1: 1.000
# ROUGE-L F1: 1.000
#
# Test Sample 8
# ------------------------------
# Operation Type: arithmetic
# Question: what portion of equity compensation plan is to be issued upon exercise of outstanding options warrants and rights?
# Expected Operations: 1955024 / (1955024 + 4078093)
# Expected Answer: 32.4%
#
# All Generated Responses:
#
# Generation 1:
# Operations needed: (1955024 / 4078093) * 100
# Answer: 48.05% ---
#
# Generation 2:
# Operations needed: (1955024 / (1955024 + 4078093))
# Answer: 0.3296 or 32.96% ---
#
# Generation 3:
# Operations needed: (1955024 / 4078093) * 100
# Answer: 48.07% ---
#
# Generation 4:
# Operations needed: (1955024 / 4078093)
# Answer: 48.0% ---
#
# Generation 5:
# Operations needed: (1955024 / 1955024) * 100
# Answer: 100
#
# Consensus from multiple generations:
# Operations needed: (1955024 / 4078093) * 100
# Answer: 48.05% ---
#
# ROUGE Scores:
# ROUGE-1 F1: 0.600
# ROUGE-2 F1: 0.000
# ROUGE-L F1: 0.400
#
# Test Sample 9
# ------------------------------
# Operation Type: arithmetic
# Question: what was the change in other income from 2010 to 2011 in millions?
# Expected Operations: 112 - 54
# Expected Answer: 58
#
# All Generated Responses:
#
# Generation 1:
# Operations needed: (112 - 54)
# Answer: 58
#
# Generation 2:
# Operations needed: (112 - 54)
# Answer: 58
#
# Generation 3:
# Operations needed: (112 - 54)
# Answer: 58
#
# Generation 4:
# Operations needed: (112 - 54)
# Answer: 58
#
# Generation 5:
# Operations needed: (112 - 54)
# Answer: 58
#
# Consensus from multiple generations:
# Operations needed: (112 - 54)
# Answer: 58
#
# ROUGE Scores:
# ROUGE-1 F1: 0.333
# ROUGE-2 F1: 0.000
# ROUGE-L F1: 0.333
#
# Test Sample 10
# ------------------------------
# Operation Type: arithmetic
# Question: considering the year 2016 , what is the percentage of unproved properties among the total properties?
# Expected Operations: 3840126 / 49592091
# Expected Answer: 7.74%
#
# All Generated Responses:
#
# Generation 1:
# Operations needed: (3840126 / 49592091) * 100
# Answer: 7.73%
#
# Generation 2:
# Operations needed: (3840126 / 49592091) * 100
# Answer: 7.73% ---
#
# Generation 3:
# Operations needed: (3840126 / 49592091) * 100
# Answer: 7.73%
#
# Generation 4:
# Operations needed: (3840126 / 49592091) * 100
# Answer: 7.73%---
#
# Generation 5:
# Operations needed: (3840126 / 49592091) * 100
# Answer: 7.73%
#
# Consensus from multiple generations:
# Operations needed: (3840126 / 49592091) * 100
# Answer: 7.73%
#
# ROUGE Scores:
# ROUGE-1 F1: 0.250
# ROUGE-2 F1: 0.000
# ROUGE-L F1: 0.250
#
# Overall ROUGE Scores:
# ==================================================
# Average ROUGE-1 F1: 0.534
# Average ROUGE-2 F1: 0.296
# Average ROUGE-L F1: 0.514
